# %% [markdown]
# # Data explorations
# In this notebook, a first analysis of the data from [Wang (2017)](https://arxiv.org/abs/1705.00648) will be performed.

# %%
import pandas as pd
import numpy as np
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# #### Data loading class for interaction with the data

# %%
# Adds a reference to the file which holds data interactivity functions
exec(open('data_loader.py').read())

# %%
# DataLoader is a class from the file above
data = DataLoader()
data.df['train']
# Out:
#                   label                                          statement  \
# id
# 2635.json         false  Says the Annies List political group supports ...
# 10540.json    half-true  When did the decline of coal start? It started...
# 324.json    mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 1123.json         false  Health care reform legislation is likely to ma...
# 9028.json     half-true  The economic turnaround started at the end of ...
# 12465.json         true  The Chicago Bears have had more starting quart...
# 2342.json   barely-true  Jim Dunnam has not lived in the district he re...
# 153.json      half-true  I'm the only person on this stage who has work...
# 5602.json     half-true  However, it took $19.5 million in Oregon Lotte...
# 9741.json   mostly-true  Says GOP primary opponents Glenn Grothman and ...
# 7115.json   mostly-true  For the first time in history, the share of th...
# 4148.json     half-true  Since 2000, nearly 12 million Americans have s...
# 5947.json         false  When Mitt Romney was governor of Massachusetts...
# 8616.json   mostly-true  The economy bled $24 billion due to the govern...
# 8705.json   barely-true  Most of the (Affordable Care Act) has already ...
# 10683.json    half-true  In this last election in November, ... 63 perc...
# 620.json           true  McCain opposed a requirement that the governme...
# 3863.json   barely-true  U.S. Rep. Ron Kind, D-Wis., and his fellow Dem...
# 12372.json    half-true  Water rates in Manila, Philippines, were raise...
# 12385.json  mostly-true  Almost 100,000 people left Puerto Rico last year.
# 10173.json        false  Women and men both are making less when you ad...
# 9867.json   mostly-true  The United States has the highest corporate ta...
# 12408.json  mostly-true  We just had the best year for the auto industr...
# 2673.json     half-true  Says Scott Walker favors cutting up to 350,000...
# 7057.json   barely-true  Says Mitt Romney wants to get rid of Planned P...
# 10215.json        false              I dont know who (Jonathan Gruber) is.
# 12517.json  mostly-true  Hate crimes against American Muslims and mosqu...
# 3910.json     half-true  Rick Perry has never lost an election and rema...
# 11092.json        false  ISIS supporter tweeted at 10:34 a.m. Shooting ...
# 12163.json  mostly-true  Youth unemployment in minority communities is ...
# ...                 ...                                                ...
# 8119.json          true  Since the Affordable Care Act passed, 90 perce...
# 1550.json          true  Debt has almost doubled in Austin under Gov. P...
# 4077.json     half-true  Lets say (Republicans) take away half of our d...
# 11207.json  barely-true  Theres a tremendous other number of public off...
# 4216.json         false  Under last years health care reform, a bunch o...
# 9365.json   barely-true  The Obama administration spent $205,075 in sti...
# 981.json          false  There has been no net global warming for over ...
# 11074.json    half-true  Thanks to the Obama administrations negotiatio...
# 1674.json         false  This race will be the Democrats top target thi...
# 6032.json     half-true  Georgia Public Service Commission member Stan ...
# 7388.json   mostly-true  Says he and Mitt Romney agreed on tying minimu...
# 10166.json        false  As a result of Obamacare, California seniors f...
# 8371.json          true  For the first time since the Korean War, total...
# 3744.json   mostly-true  Says Rick Perry turned down our invitation to ...
# 8262.json   barely-true  In 2012, the state put together a list of over...
# 1918.json     half-true  The Republican Party lost 1.1 million register...
# 4614.json   mostly-true  The proudest accomplishment (of my tenure) was...
# 13344.json   pants-fire  Recently though, the media has reported on tho...
# 13239.json  barely-true  Stopped by Smiley Cookie to pick up some great...
# 4423.json   mostly-true   Mike Trainor...still owes $250,000 to the state.
# 11018.json  barely-true  The Supreme Courts views are radically out of ...
# 2930.json     half-true  When it comes to the state deficit, Wisconsin ...
# 4886.json     half-true  Eighty percent of the net new jobs created in ...
# 4388.json    pants-fire  Mayor Fung wants to punish our childrens educa...
# 1592.json     half-true  Under the ruling of the Supreme Court, any lob...
# 5473.json   mostly-true  There are a larger number of shark attacks in ...
# 3408.json   mostly-true  Democrats have now become the party of the [At...
# 3959.json     half-true  Says an alternative to Social Security that op...
# 2253.json         false  On lifting the U.S. Cuban embargo and allowing...
# 1155.json    pants-fire  The Department of Veterans Affairs has a manua...
#
#                                                      subjects  \
# id
# 2635.json                                            abortion
# 10540.json                 energy,history,job-accomplishments
# 324.json                                       foreign-policy
# 1123.json                                         health-care
# 9028.json                                        economy,jobs
# 12465.json                                          education
# 2342.json                                candidates-biography
# 153.json                                               ethics
# 5602.json                                                jobs
# 9741.json           energy,message-machine-2014,voting-record
# 7115.json                                           elections
# 4148.json             economy,jobs,new-hampshire-2012,poverty
# 5947.json                                history,state-budget
# 8616.json                  economy,federal-budget,health-care
# 8705.json                                         health-care
# 10683.json                                          elections
# 620.json                                       federal-budget
# 3863.json                                      federal-budget
# 12372.json          financial-regulation,foreign-policy,water
# 12385.json                      bankruptcy,economy,population
# 10173.json                                     economy,income
# 9867.json                                  corporations,taxes
# 12408.json                                            economy
# 2673.json                         health-care,message-machine
# 7057.json                 abortion,federal-budget,health-care
# 10215.json                                        health-care
# 12517.json        crime,diversity,homeland-security,terrorism
# 3910.json                                candidates-biography
# 11092.json                               technology,terrorism
# 12163.json                             diversity,economy,jobs
# ...                                                       ...
# 8119.json                                economy,jobs,workers
# 1550.json                                             economy
# 4077.json                                           elections
# 11207.json                            technology,transparency
# 4216.json                                         health-care
# 9365.json                                    economy,stimulus
# 981.json                           climate-change,environment
# 11074.json           foreign-policy,homeland-security,nuclear
# 1674.json                                    elections,states
# 6032.json                                    campaign-finance
# 7388.json                                     poverty,workers
# 10166.json  federal-budget,health-care,medicare,message-ma...
# 8371.json                                      federal-budget
# 3744.json                          bipartisanship,immigration
# 8262.json                                           elections
# 1918.json                            bipartisanship,elections
# 4614.json                   state-budget,state-finances,taxes
# 13344.json                                          elections
# 13239.json                                               food
# 4423.json                     bankruptcy,economy,legal-issues
# 11018.json              gays-and-lesbians,polls,supreme-court
# 2930.json                                        state-budget
# 4886.json                                        economy,jobs
# 4388.json   children,city-budget,deficit,education,state-b...
# 1592.json                              corporations,elections
# 5473.json                                   animals,elections
# 3408.json                                           elections
# 3959.json                          retirement,social-security
# 2253.json                              florida,foreign-policy
# 1155.json                                health-care,veterans
#
#                                                 speaker  \
# id
# 2635.json                                  dwayne-bohac
# 10540.json                               scott-surovell
# 324.json                                   barack-obama
# 1123.json                                  blog-posting
# 9028.json                                 charlie-crist
# 12465.json                                    robin-vos
# 2342.json                        republican-party-texas
# 153.json                                   barack-obama
# 5602.json                                oregon-lottery
# 9741.json                                 duey-stroebel
# 7115.json                               robert-menendez
# 4148.json                                      bernie-s
# 5947.json                                   mitt-romney
# 8616.json                                    doonesbury
# 8705.json                                   george-will
# 10683.json                                     bernie-s
# 620.json                                   barack-obama
# 3863.json   national-republican-congressional-committee
# 12372.json                                   gwen-moore
# 12385.json                                     jack-lew
# 10173.json                            dennis-richardson
# 9867.json                                  eric-bolling
# 12408.json                              hillary-clinton
# 2673.json              greater-wisconsin-political-fund
# 7057.json                planned-parenthood-action-fund
# 10215.json                                 nancy-pelosi
# 12517.json                              hillary-clinton
# 3910.json                                    ted-nugent
# 11092.json                                pamela-geller
# 12163.json                                 peter-kinder
# ...                                                 ...
# 8119.json                                  alan-krueger
# 1550.json                                    bill-white
# 4077.json                              will-weatherford
# 11207.json                                  howard-dean
# 4216.json                                  phil-gingrey
# 9365.json                                      ted-cruz
# 981.json                                 cato-institute
# 11074.json                                    don-beyer
# 1674.json                                debra-lehrmann
# 6032.json                                  pam-davidson
# 7388.json                                  barack-obama
# 10166.json                          american-crossroads
# 8371.json                                   dennis-ross
# 3744.json                                    jay-carney
# 8262.json                                 charlie-crist
# 1918.json                       libertarian-party-texas
# 4614.json                             christine-whitman
# 13344.json                                john-rafferty
# 13239.json                                 donald-trump
# 4423.json                          vincent-buddy-cianci
# 11018.json                                     ted-cruz
# 2930.json                               alberta-darling
# 4886.json                                    david-frum
# 4388.json                               richard-tomlins
# 1592.json                                 david-axelrod
# 5473.json                                  aclu-florida
# 3408.json                                   alan-powell
# 3959.json                                   herman-cain
# 2253.json                                   jeff-greene
# 1155.json                                michael-steele
#
#                                                   speaker_job  \
# id
# 2635.json                                State representative
# 10540.json                                     State delegate
# 324.json                                            President
# 1123.json                                                 NaN
# 9028.json                                                 NaN
# 12465.json                         Wisconsin Assembly speaker
# 2342.json                                                 NaN
# 153.json                                            President
# 5602.json                                                 NaN
# 9741.json                                State representative
# 7115.json                                        U.S. Senator
# 4148.json                                        U.S. Senator
# 5947.json                                     Former governor
# 8616.json                                                 NaN
# 8705.json                                           Columnist
# 10683.json                                       U.S. Senator
# 620.json                                            President
# 3863.json                                                 NaN
# 12372.json                  U.S. House member -- 4th District
# 12385.json                                Treasury secretary
# 10173.json                               state representative
# 9867.json            Co-host on Fox News Channel's "The Five"
# 12408.json                             Presidential candidate
# 2673.json                                                 NaN
# 7057.json                                      Advocacy group
# 10215.json                              House Minority Leader
# 12517.json                             Presidential candidate
# 3910.json                                            musician
# 11092.json  President of American Freedom Defense Intitiative
# 12163.json                                Lieutenant governor
# ...                                                       ...
# 8119.json        Chairman of the Council of Economic Advisers
# 1550.json                             Former mayor of Houston
# 4077.json                                State Representative
# 11207.json             Democratic National Committee chairman
# 4216.json                                    U.S. Congressman
# 9365.json                                             Senator
# 981.json                                                  NaN
# 11074.json               8th District congressional candidate
# 1674.json                                                 NaN
# 6032.json                                                 NaN
# 7388.json                                           President
# 10166.json                                                NaN
# 8371.json                       U.S. House of Representatives
# 3744.json                         White House press secretary
# 8262.json                                                 NaN
# 1918.json                                                 NaN
# 4614.json               President, The Whitman Strategy Group
# 13344.json                                      State Senator
# 13239.json                                    President-Elect
# 4423.json                                                 NaN
# 11018.json                                            Senator
# 2930.json                         State Senator, 8th District
# 4886.json                         Senior editor, The Atlantic
# 4388.json                                                 NaN
# 1592.json                                                 NaN
# 5473.json                                                 NaN
# 3408.json                                                 NaN
# 3959.json                                                 NaN
# 2253.json                                                 NaN
# 1155.json       chairman of the Republican National Committee
#
#                            state         party  barely_true_count  \
# id
# 2635.json                  Texas    republican                0.0
# 10540.json              Virginia      democrat                0.0
# 324.json                Illinois      democrat               70.0
# 1123.json                    NaN          none                7.0
# 9028.json                Florida      democrat               15.0
# 12465.json             Wisconsin    republican                0.0
# 2342.json                  Texas    republican                3.0
# 153.json                Illinois      democrat               70.0
# 5602.json                    NaN  organization                0.0
# 9741.json              Wisconsin    republican                0.0
# 7115.json             New Jersey      democrat                1.0
# 4148.json                Vermont   independent               18.0
# 5947.json          Massachusetts    republican               34.0
# 8616.json                    NaN          none                0.0
# 8705.json               Maryland     columnist                7.0
# 10683.json               Vermont   independent               18.0
# 620.json                Illinois      democrat               70.0
# 3863.json                    NaN    republican               18.0
# 12372.json             Wisconsin      democrat                3.0
# 12385.json     Washington, D.C.       democrat                0.0
# 10173.json                Oregon    republican                0.0
# 9867.json                    NaN          none                2.0
# 12408.json              New York      democrat               40.0
# 2673.json              Wisconsin          none                3.0
# 7057.json       Washington, D.C.          none                1.0
# 10215.json            California      democrat                3.0
# 12517.json              New York      democrat               40.0
# 3910.json                  Texas    republican                0.0
# 11092.json              New York      activist                0.0
# 12163.json              Missouri    republican                0.0
# ...                          ...           ...                ...
# 8119.json       Washington, D.C.      democrat                0.0
# 1550.json                  Texas      democrat                2.0
# 4077.json                Florida    republican                2.0
# 11207.json               Vermont      democrat                1.0
# 4216.json                Georgia    republican                2.0
# 9365.json                  Texas    republican               36.0
# 981.json                     NaN   libertarian                0.0
# 11074.json              Virginia      democrat                1.0
# 1674.json                    NaN    republican                0.0
# 6032.json                Georgia    republican                0.0
# 7388.json               Illinois      democrat               70.0
# 10166.json                   NaN    republican                5.0
# 8371.json                Florida    republican                0.0
# 3744.json   District of Columbia          none                2.0
# 8262.json                Florida      democrat               15.0
# 1918.json                  Texas   libertarian                0.0
# 4614.json             New Jersey    republican                0.0
# 13344.json          Pennsylvania    republican                0.0
# 13239.json              New York    republican               63.0
# 4423.json           Rhode Island   independent                0.0
# 11018.json                 Texas    republican               36.0
# 2930.json              Wisconsin    republican                1.0
# 4886.json                    NaN          none                0.0
# 4388.json           Rhode Island      democrat                0.0
# 1592.json                    NaN      democrat                2.0
# 5473.json                Florida          none                0.0
# 3408.json                Georgia    republican                0.0
# 3959.json                Georgia    republican                4.0
# 2253.json                Florida      democrat                3.0
# 1155.json               Maryland    republican                0.0
#
#             false_count  half_true_count  mostly_true_count  \
# id
# 2635.json           1.0              0.0                0.0
# 10540.json          0.0              1.0                1.0
# 324.json           71.0            160.0              163.0
# 1123.json          19.0              3.0                5.0
# 9028.json           9.0             20.0               19.0
# 12465.json          3.0              2.0                5.0
# 2342.json           1.0              1.0                3.0
# 153.json           71.0            160.0              163.0
# 5602.json           0.0              1.0                0.0
# 9741.json           0.0              0.0                1.0
# 7115.json           3.0              1.0                3.0
# 4148.json          12.0             22.0               41.0
# 5947.json          32.0             58.0               33.0
# 8616.json           0.0              2.0                4.0
# 8705.json           6.0              3.0                5.0
# 10683.json         12.0             22.0               41.0
# 620.json           71.0            160.0              163.0
# 3863.json           9.0              8.0                5.0
# 12372.json          4.0              4.0                3.0
# 12385.json          1.0              0.0                1.0
# 10173.json          4.0              1.0                2.0
# 9867.json           1.0              1.0                1.0
# 12408.json         29.0             69.0               76.0
# 2673.json           3.0              3.0                1.0
# 7057.json           0.0              0.0                0.0
# 10215.json          7.0             11.0                2.0
# 12517.json         29.0             69.0               76.0
# 3910.json           0.0              2.0                0.0
# 11092.json          1.0              1.0                0.0
# 12163.json          0.0              0.0                1.0
# ...                 ...              ...                ...
# 8119.json           0.0              0.0                0.0
# 1550.json           3.0              5.0                7.0
# 4077.json           3.0              4.0                3.0
# 11207.json          4.0              1.0                2.0
# 4216.json           5.0              2.0                1.0
# 9365.json          33.0             15.0               19.0
# 981.json            1.0              0.0                0.0
# 11074.json          2.0              1.0                3.0
# 1674.json           1.0              0.0                0.0
# 6032.json           0.0              1.0                0.0
# 7388.json          71.0            160.0              163.0
# 10166.json          5.0              4.0                0.0
# 8371.json           0.0              0.0                0.0
# 3744.json           2.0              1.0                2.0
# 8262.json           9.0             20.0               19.0
# 1918.json           0.0              1.0                0.0
# 4614.json           0.0              0.0                2.0
# 13344.json          0.0              0.0                0.0
# 13239.json        114.0             51.0               37.0
# 4423.json           2.0              1.0                2.0
# 11018.json         33.0             15.0               19.0
# 2930.json           1.0              2.0                1.0
# 4886.json           0.0              1.0                1.0
# 4388.json           0.0              0.0                0.0
# 1592.json           1.0              6.0                7.0
# 5473.json           1.0              1.0                1.0
# 3408.json           0.0              0.0                1.0
# 3959.json          11.0              5.0                3.0
# 2253.json           1.0              3.0                0.0
# 1155.json           1.0              1.0                0.0
#
#             pants_on_fire_count  \
# id
# 2635.json                   0.0
# 10540.json                  0.0
# 324.json                    9.0
# 1123.json                  44.0
# 9028.json                   2.0
# 12465.json                  1.0
# 2342.json                   1.0
# 153.json                    9.0
# 5602.json                   1.0
# 9741.json                   0.0
# 7115.json                   0.0
# 4148.json                   0.0
# 5947.json                  19.0
# 8616.json                   0.0
# 8705.json                   1.0
# 10683.json                  0.0
# 620.json                    9.0
# 3863.json                   8.0
# 12372.json                  1.0
# 12385.json                  0.0
# 10173.json                  0.0
# 9867.json                   0.0
# 12408.json                  7.0
# 2673.json                   1.0
# 7057.json                   0.0
# 10215.json                  3.0
# 12517.json                  7.0
# 3910.json                   2.0
# 11092.json                  0.0
# 12163.json                  1.0
# ...                         ...
# 8119.json                   0.0
# 1550.json                   3.0
# 4077.json                   0.0
# 11207.json                  0.0
# 4216.json                   1.0
# 9365.json                   8.0
# 981.json                    0.0
# 11074.json                  0.0
# 1674.json                   0.0
# 6032.json                   0.0
# 7388.json                   9.0
# 10166.json                  0.0
# 8371.json                   0.0
# 3744.json                   0.0
# 8262.json                   2.0
# 1918.json                   0.0
# 4614.json                   0.0
# 13344.json                  1.0
# 13239.json                 61.0
# 4423.json                   1.0
# 11018.json                  8.0
# 2930.json                   1.0
# 4886.json                   0.0
# 4388.json                   1.0
# 1592.json                   0.0
# 5473.json                   0.0
# 3408.json                   0.0
# 3959.json                   3.0
# 2253.json                   0.0
# 1155.json                   2.0
#
#                                                       context
# id
# 2635.json                                            a mailer
# 10540.json                                    a floor speech.
# 324.json                                               Denver
# 1123.json                                      a news release
# 9028.json                                 an interview on CNN
# 12465.json                          a an online opinion-piece
# 2342.json                                    a press release.
# 153.json             a Democratic debate in Philadelphia, Pa.
# 5602.json                                          a website
# 9741.json                                     an online video
# 7115.json                                            a speech
# 4148.json                                             a tweet
# 5947.json                          an interview with CBN News
# 8616.json             a Doonesbury strip in the Sunday comics
# 8705.json                       comments on "Fox News Sunday"
# 10683.json                       a town hall in Austin, Texas
# 620.json                                           a radio ad
# 3863.json                                      a news release
# 12372.json                            a congressional hearing
# 12385.json                   an interview with Bloomberg News
# 10173.json                                  a campaign debate
# 9867.json                a discussion on Fox News' "The Five"
# 12408.json                        remarks at a Kentucky rally
# 2673.json                                    a campaign TV ad
# 7057.json                                          a radio ad
# 10215.json                                  a news conference
# 12517.json       a speech after a terrorist attack in Orlando
# 3910.json                                     an oped column.
# 11092.json                                           a tweet
# 12163.json                             a gubernatorial debate
# ...                                                       ...
# 8119.json              an interview with Bloomberg television
# 1550.json                                            a speech
# 4077.json   an interview with the "St. Petersburg Times" e...
# 11207.json                      an interview on "Morning Joe"
# 4216.json                                   a news conference
# 9365.json                                            a report
# 981.json                           a political advertisement.
# 11074.json                                           an op-ed
# 1674.json                                            a mailer
# 6032.json                                         a statement
# 7388.json                      the State of the Union address
# 10166.json                                      a campaign ad
# 8371.json                     an op-ed in the Tampa Bay Times
# 3744.json                a press gaggle aboard Air Force One.
# 8262.json                     a speech to Louisiana Democrats
# 1918.json                                     a press release
# 4614.json                                an interview on NJTV
# 13344.json                                          a debate.
# 13239.json                                   a Facebook post.
# 4423.json                              a talk show discussion
# 11018.json                                an interview on NPR
# 2930.json                              a television interview
# 4886.json                        a New York magazine article.
# 4388.json   a recorded telephone message to Cranston resid...
# 1592.json                     an interview on ABC's This Week
# 5473.json                   interview on "The Colbert Report"
# 3408.json                                        an interview
# 3959.json                    a Republican presidential debate
# 2253.json   a televised debate on Miami's WPLG-10 against ...
# 1155.json                                a Fox News interview
#
# [10240 rows x 13 columns]

# %% [markdown]
# <hr>
# ## Testing descriptive statistics
# To ensure the dataset has not been adjusted, we need to combine the three datasets and compare some counts with the listings in the research article. The following dataset statistics should be present:
#
# | Dataset statistics             |        || Top-3 Speaker Affiliations |       |
# |--------------------------------|--------||----------------------------|-------|
# | Training set size              | 10,269 || Democrats                  | 4,150 |
# | Validation set size            | 1,284  || Republicans                | 5,687 |
# | Testing set size               | 1,283  || None (e.g., FB posts)      | 2,185 |
# | Avg. statement length (tokens) | 17.9   |

# %%
print({
    'Training set size': len(data.df['train'].label),
    'Validation set size': len(data.df['validation'].label),
    'Testing set size': len(data.df['test'].label),
    'Avg. statement length (tokens)': pd.concat([data.df['train'].statement, data.df['test'].statement, data.df['validation'].statement]).apply(lambda x: len(x.split(' '))).mean(),
})

affil_col = pd.concat([data.df['train'].party, data.df['test'].party, data.df['validation'].party])
print({
    'Democrats': len(list(filter(lambda x: x == 'democrat', affil_col.values))),
    'Republicans': len(list(filter(lambda x: x == 'republican', affil_col.values))),
    'None': len(list(filter(lambda x: x == 'none', affil_col.values))),
})
# Out:
# {'Training set size': 10240, 'Validation set size': 1284, 'Testing set size': 1267, 'Avg. statement length (tokens)': 17.991947463059965}
# {'Democrats': 4137, 'Republicans': 5665, 'None': 2181}

# %% [markdown]
# Although there are minor differences, we can conclude that the dataset from the research article has not been adjusted heavily since release.
# <hr>

# %% [markdown]
# ## Analysis of data
# To get a better idea of the context of the statements, it might be interesting to look at some statistics surrounding the subjects.

# %%
subjects = []

for subject in pd.concat([data.df['train'].subjects, data.df['test'].subjects, data.df['validation'].subjects]).values:
    try:
        subjects.append(subject.split(','))
    except:
        pass

subjects = np.concatenate(subjects)

# %%
subjects_counter = Counter(subjects)
wordcloud = WordCloud(width = 3000, height = 1000, background_color = 'white').generate_from_frequencies(subjects_counter)

plt.figure(figsize = (25, 20))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
sorted_subjects = subjects_counter.most_common(len(subjects_counter.keys()))

chart = [go.Bar(
            x = list(map(lambda x: x[0], sorted_subjects)),
            y = list(map(lambda x: x[1], sorted_subjects)),
        )]

iplot(chart)
# Out:
# <div id="a995f7d0-9c56-4600-9a4f-862c6d206fe6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("a995f7d0-9c56-4600-9a4f-862c6d206fe6")) {
#     Plotly.newPlot("a995f7d0-9c56-4600-9a4f-862c6d206fe6", [{"x": ["economy", "health-care", "taxes", "federal-budget", "education", "jobs", "state-budget", "candidates-biography", "elections", "immigration", "foreign-policy", "crime", "history", "energy", "environment", "legal-issues", "guns", "military", "job-accomplishments", "terrorism", "workers", "transportation", "message-machine-2012", "state-finances", "abortion", "criminal-justice", "states", "public-health", "deficit", "pundits", "women", "message-machine", "medicare", "voting-record", "labor", "corrections-and-updates", "campaign-finance", "children", "congress", "poverty", "stimulus", "government-regulation", "income", "ethics", "government-efficiency", "climate-change", "religion", "corporations", "public-safety", "city-government", "social-security", "iraq", "polls", "debt", "families", "market-regulation", "gays-and-lesbians", "civil-rights", "homeland-security", "trade", "financial-regulation", "abc-news-week", "drugs", "supreme-court", "bipartisanship", "medicaid", "diversity", "housing", "retirement", "unions", "city-budget", "sports", "small-business", "science", "campaign-advertising", "veterans", "transparency", "nuclear", "agriculture", "technology", "debates", "marijuana", "new-hampshire-2012", "human-rights", "marriage", "county-government", "welfare", "congressional-rules", "county-budget", "wealth", "infrastructure", "florida", "water", "oil-spill", "population", "afghanistan", "pensions", "animals", "sexuality", "china", "message-machine-2014", "israel", "recreation", "pop-culture", "cap-and-trade", "bush-administration", "weather", "islam", "census", "gambling", "redistricting", "bankruptcy", "consumer-safety", "Alcohol", "gas-prices", "public-service", "patriotism", "tourism", "food-safety", "obama-birth-certificate", "privacy", "hunger", "disability", "urban", "ebola", "baseball", "occupy-wall-street", "florida-amendments", "space", "kagan-nomination", "natural-disasters", "sotomayor-nomination", "fake-news", "lottery", "10-news-tampa-bay", "autism", "colbert-report", "after-the-fact", "food", "death-penalty", "homeless", "fires", "nightlife", "politifacts-top-promises"], "y": [1432, 1426, 1218, 937, 926, 899, 879, 805, 757, 642, 604, 553, 498, 479, 436, 428, 404, 389, 364, 362, 351, 339, 323, 314, 313, 311, 287, 283, 267, 263, 258, 255, 245, 242, 242, 239, 235, 234, 231, 226, 224, 218, 217, 208, 187, 174, 174, 173, 168, 164, 163, 162, 157, 150, 145, 144, 139, 137, 131, 125, 123, 119, 115, 111, 110, 110, 108, 104, 101, 100, 96, 95, 91, 91, 90, 85, 85, 83, 83, 82, 80, 77, 76, 72, 71, 71, 70, 69, 68, 67, 67, 66, 64, 64, 61, 60, 59, 59, 58, 56, 55, 50, 48, 47, 44, 44, 44, 42, 42, 41, 41, 40, 40, 40, 38, 36, 35, 33, 32, 31, 30, 28, 27, 27, 24, 21, 19, 18, 17, 12, 12, 12, 10, 6, 6, 3, 3, 2, 2, 2, 1, 1, 1, 1], "type": "bar", "uid": "64cb5edb-4c54-48a9-952e-7b77f5a80dd9"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("a995f7d0-9c56-4600-9a4f-862c6d206fe6")) {window._Plotly.Plots.resize(document.getElementById("a995f7d0-9c56-4600-9a4f-862c6d206fe6"));};})</script>

# %%
sorted_parties = Counter(pd.concat([data.df['train'].party, data.df['test'].party, data.df['validation'].party]).values).most_common(len(subjects_counter.keys()))

chart = [go.Bar(
            x = list(map(lambda x: x[0], sorted_parties)),
            y = list(map(lambda x: x[1], sorted_parties)),
        )]

iplot(chart)
# Out:
# <div id="f897bb2d-8811-43e9-a510-2efbe57940ad" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("f897bb2d-8811-43e9-a510-2efbe57940ad")) {
#     Plotly.newPlot("f897bb2d-8811-43e9-a510-2efbe57940ad", [{"x": ["republican", "democrat", "none", "organization", "independent", "newsmaker", "libertarian", "journalist", "activist", "columnist", "talk-show-host", "state-official", "labor-leader", "business-leader", "tea-party-member", "education-official", "green", "constitution-party", null, "government-body", "county-commissioner", "liberal-party-canada", "Moderate", "democratic-farmer-labor", "ocean-state-tea-party-action"], "y": [5665, 4137, 2181, 264, 180, 64, 51, 49, 45, 44, 32, 24, 15, 11, 10, 3, 3, 3, 2, 2, 2, 1, 1, 1, 1], "type": "bar", "uid": "a9bb75de-524f-4a13-acdd-aabc74bd04a4"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("f897bb2d-8811-43e9-a510-2efbe57940ad")) {window._Plotly.Plots.resize(document.getElementById("f897bb2d-8811-43e9-a510-2efbe57940ad"));};})</script>

# %%
labels = Counter(pd.concat([data.df['train'].label, data.df['test'].label, data.df['validation'].label]).values)

chart = [go.Pie(
            labels = list(labels.keys()),
            values = list(labels.values()),
        )]

iplot(chart)
# Out:
# <div id="7a35389e-376e-471b-99d7-d24d33383eec" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("7a35389e-376e-471b-99d7-d24d33383eec")) {
#     Plotly.newPlot("7a35389e-376e-471b-99d7-d24d33383eec", [{"labels": ["false", "half-true", "mostly-true", "true", "barely-true", "pants-fire"], "values": [2507, 2627, 2454, 2053, 2103, 1047], "type": "pie", "uid": "cfdfbb7b-e74f-49d4-9670-d64bc12586b5"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("7a35389e-376e-471b-99d7-d24d33383eec")) {window._Plotly.Plots.resize(document.getElementById("7a35389e-376e-471b-99d7-d24d33383eec"));};})</script>

# %% [markdown]
# <hr>
